# %%
import pandas as pd

# %%
df = pd.read_csv("D:/KnowAll/documents/Khảo sát về hành vi tiêu thụ đồ uống có cồn (Responses) - Form responses 1.csv")
df.head()
# Out:
#              Timestamp Hiện tại bạn đang bao nhiêu tuổi ? Bạn hiện là?  \
# 0  06/03/2023 22:00:08                              18-23          NaN
# 1  06/03/2023 22:01:25                              24-29          NaN
# 2  06/03/2023 22:04:21                              18-23          NaN
# 3  06/03/2023 22:06:39                              18-23          NaN
# 4  06/03/2023 22:06:46                              18-23          NaN
#
#   Khi cân nhắc tiêu thụ sản phẩm có cồn bạn quan tâm đến điều gì ?  \
# 0                                         Chất lượng
# 1                                                Giá
# 2                       Chất lượng, Giá, Thương hiệu
# 3                                        Thương hiệu
# 4                                         Chất lượng
#
#   Khi nhắc đến đồ uống có cồn bạn sẽ nhảy số ngay đến từ khóa nào  \
# 0                         Những người anh em, Tụ tập
# 1                                             Tụ tập
# ...

# %%
df2 = pd.read_csv("D:/KnowAll/documents/KHẢO SÁT VỀ NHU CẦU MUA ĐỒ DECOR BÀN LÀM VIỆC (Câu trả lời) - Câu trả lời biểu mẫu 1.csv")
df2.head()
# Out:
#          Dấu thời gian 1. Anh/chị đang ở trong độ tuổi nào dưới đây ?  \
# 0  05/06/2023 14:38:50                                        20 - 30
# 1  05/06/2023 14:38:55                                        20 - 30
# 2  05/06/2023 14:39:54                                        20 - 30
# 3  05/06/2023 14:40:00                                        20 - 30
# 4  05/06/2023 14:40:56                                        20 - 30
#
#   2. Anh/chị đang ở khu vực nào của Hà Nội? 3. Hiện nay anh/chị đang là ?  \
# 0                            Quận Nội Thành           Học sinh, sinh viên
# 1                            Quận Nội Thành           Nhân viên văn phòng
# 2                            Quận Nội Thành           Nhân viên văn phòng
# 3                         Huyện Ngoại Thành           Học sinh, sinh viên
# 4                            Quận Nội Thành           Học sinh, sinh viên
#
#   4. Hiện nay, thu nhập của anh/chị nằm trong khoảng  \
# ...
